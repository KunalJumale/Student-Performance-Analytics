# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("C:/Users/jumal/OneDrive/Desktop/Data Analyst/SQL/Student Performance Analytics/Student Performance Analytics.csv")
df
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Display top 5 rows dataset
df.head()
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
# 3         4         305           5  28-12-2023      Quiz     95     A
# 4         5         830           3  27-02-2025     Final     18     F
#
#    class_id class_name section  ...   age  class_id.1                city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0        Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0         Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0        Andersonstad
# 3       4.0    Grade 9       B  ...  10.0        24.0  Lake Cherylchester
# 4       5.0    Grade 8       C  ...  17.0         5.0   North Michaelview
#
#   subject_id.1  subject_name  teacher_id teacher_id.1           name.1  \
# ...

# %%
# Display summary 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   score_id           20000 non-null  int64
#  1   student_id         20000 non-null  int64
#  2   subject_id         20000 non-null  int64
#  3   test_date          20000 non-null  object
#  4   test_type          20000 non-null  object
#  5   score              20000 non-null  int64
#  6   grade              20000 non-null  object
#  7   class_id           30 non-null     float64
#  8   class_name         30 non-null     object
#  9   section            30 non-null     object
#  10  class_teacher_id   30 non-null     float64
#  11  student_id.1       1000 non-null   float64
#  12  name               1000 non-null   object
#  13  gender             1000 non-null   object
#  14  age                1000 non-null   float64
#  15  class_id.1         1000 non-null   float64
# ...

# %%
# display only Numaricals dataset
df.describe()
# Out:
#            score_id   student_id    subject_id         score   class_id  \
# count  20000.000000  20000.00000  20000.000000  20000.000000  30.000000
# mean   10000.500000    499.22195      3.502250     49.985050  15.500000
# std     5773.647028    287.67677      1.708374     29.113483   8.803408
# min        1.000000      1.00000      1.000000      0.000000   1.000000
# 25%     5000.750000    249.00000      2.000000     25.000000   8.250000
# 50%    10000.500000    501.00000      4.000000     50.000000  15.500000
# 75%    15000.250000    747.00000      5.000000     75.000000  22.750000
# max    20000.000000   1000.00000      6.000000    100.000000  30.000000
#
#        class_teacher_id  student_id.1          age   class_id.1  subject_id.1  \
# count         30.000000   1000.000000  1000.000000  1000.000000      6.000000
# mean          10.800000    500.500000    14.053000    15.527000      3.500000
# std            5.950369    288.819436     2.581638     8.749504      1.870829
# ...

# %%
# check type of dataset
df.dtypes
# Out:
# score_id               int64
# student_id             int64
# subject_id             int64
# test_date             object
# test_type             object
# score                  int64
# grade                 object
# class_id             float64
# class_name            object
# section               object
# class_teacher_id     float64
# student_id.1         float64
# name                  object
# gender                object
# age                  float64
# class_id.1           float64
# city                  object
# subject_id.1         float64
# subject_name          object
# teacher_id           float64
# teacher_id.1         float64
# name.1                object
# experience_years     float64
# subject_specialty     object
# dtype: object

# %%
# Check dimension of dataframe
df.ndim
# Out:
# 2

# %%
# Lets check all columns present in dataframe
df.columns
# Out:
# Index(['score_id', 'student_id', 'subject_id', 'test_date', 'test_type',
#        'score', 'grade', 'class_id', 'class_name', 'section',
#        'class_teacher_id', 'student_id.1', 'name', 'gender', 'age',
#        'class_id.1', 'city', 'subject_id.1', 'subject_name', 'teacher_id',
#        'teacher_id.1', 'name.1', 'experience_years', 'subject_specialty'],
#       dtype='object')

# %%
# Identify duplicate records in Rows
df.duplicated().sum()
# Out:
# 0

# %%
# Check Duplicate values in Columns
df["student_id"].duplicated().sum()
# Out:
# 19000

# %%
df[["student_id", "class_name"]].duplicated().sum()
# Out:
# 18971

# %%
# Find shape of dataframe i.e number of rows and columns.
df.shape
# Out:
# (20000, 24)

# %%
# delete all duplicate rows
df.drop_duplicates()
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# delete duplicate columns
df.drop_duplicates(["test_date", "subject_id"])
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19834     19835         266           5  22-01-2025      Quiz     95     A
# 19869     19870         602           3  17-02-2024   Midterm     62     C
# 19932     19933         136           1  01-08-2023      Quiz     64     C
# 19990     19991         924           5  15-02-2024     Final     94     A
# 19995     19996         743           3  20-11-2023     Final     70     C
#
# ...

# %%
# How do you find missing data in a DataFrame?
df.isnull().sum()
# Out:
# score_id                 0
# student_id               0
# subject_id               0
# test_date                0
# test_type                0
# score                    0
# grade                    0
# class_id             19970
# class_name           19970
# section              19970
# class_teacher_id     19970
# student_id.1         19000
# name                 19000
# gender               19000
# age                  19000
# class_id.1           19000
# city                 19000
# subject_id.1         19994
# subject_name         19994
# teacher_id           19994
# teacher_id.1         19980
# name.1               19980
# experience_years     19980
# subject_specialty    19980
# dtype: int64

# %%
# Check for columns having null values and count of null contaning rows.
df["age"].isnull().sum()
# Out:
# 19000

# %%
df[["teacher_id", "experience_years"]].isnull().sum()
# Out:
# teacher_id          19994
# experience_years    19980
# dtype: int64

# %%
# Drops Columns/Rows that contain NaN (missing) values.
df.dropna(axis=0, inplace=False)
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
# 3         4         305           5  28-12-2023      Quiz     95     A
# 4         5         830           3  27-02-2025     Final     18     F
# 5         6         625           2  15-04-2024   Midterm     25     F
#
#    class_id class_name section  ...   age  class_id.1                city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0        Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0         Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0        Andersonstad
# 3       4.0    Grade 9       B  ...  10.0        24.0  Lake Cherylchester
# 4       5.0    Grade 8       C  ...  17.0         5.0   North Michaelview
# ...

# %%
df.dropna(axis=1, inplace=False)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# [20000 rows x 7 columns]

# %%
df.dropna(subset=["student_id"], inplace=False)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
df.dropna(subset=["score", "test_date"], inplace=False)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Find the Minimum
df["score"].min()
# Out:
# 0

# %%
# Find the Max
df["score"].max()
# Out:
# 100

# %%
# Find the Mean
df["score"].mean()
# Out:
# 49.98505

# %%
# Find the Median
df["score"].median()
# Out:
# 50.0

# %%
# Find the Mean
df["score"].mode()
# Out:
# 0    70
# Name: score, dtype: int64

# %%
df["age"].ffill()
# Out:
# 0        13.0
# 1        17.0
# 2        16.0
# 3        10.0
# 4        17.0
#          ...
# 19995    11.0
# 19996    11.0
# 19997    11.0
# 19998    11.0
# 19999    11.0
# Name: age, Length: 20000, dtype: float64

# %%
df["age"].bfill()
# Out:
# 0        13.0
# 1        17.0
# 2        16.0
# 3        10.0
# 4        17.0
#          ...
# 19995     NaN
# 19996     NaN
# 19997     NaN
# 19998     NaN
# 19999     NaN
# Name: age, Length: 20000, dtype: float64

# %%
df.ffill()
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
df.replace(np.NaN, 32)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Delete/Drop/Remove rows 2,6,5,3 from dataset
df.drop([1,2,3,4], axis=0, inplace=False)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 5             6         625           2  15-04-2024   Midterm     25     F
# 6             7         853           5  04-09-2024     Final     46     D
# 7             8         629           3  11-12-2023     Final      0     F
# 8             9         896           2  23-06-2025     Final     79     B
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Delete/Drop/Remove  columns gender, SeniorCitizen from dataset
df.drop(["score_id"], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#    student_id  subject_id   test_date test_type  score grade class_name  \
# 0         306           5  11-06-2024      Quiz     17     F    Grade 8
# 1         788           4  19-06-2024     Final     51     D    Grade 7
# 2         306           6  04-06-2025      Quiz     87     B    Grade 8
#
#   section           name gender   age          city subject_name  \
# 0       A  Steven Austin      M  13.0  Johnsonmouth         Math
# 1       A    Larry Davis      M  17.0   Acevedofort      Science
# 2       C     Kevin Pugh      F  16.0  Andersonstad      English
#
#             name.1  experience_years subject_specialty
# 0     Monica Greer              30.0           Science
# 1  William Navarro              10.0         Geography
# 2       Erin Doyle               5.0           History

# %%
df.drop(["student_id.1", "teacher_id"], axis=1, inplace=True)

# %%
df.drop(["class_id", "class_teacher_id", "class_id.1", "subject_id.1"], axis=1, inplace=True)

# %%
df.drop(["teacher_id.1"], axis=1, inplace=True)

# %%
# Show only perticular Columns from Dataset
df[["test_type","class_name"]].head(6)
# Out:
#   test_type class_name
# 0      Quiz    Grade 8
# 1     Final    Grade 7
# 2      Quiz    Grade 8
# 3      Quiz    Grade 9
# 4     Final    Grade 8
# 5   Midterm   Grade 12

# %%
df.head(3)
# Out:
#    student_id  subject_id   test_date test_type  score grade class_name  \
# 0         306           5  11-06-2024      Quiz     17     F    Grade 8
# 1         788           4  19-06-2024     Final     51     D    Grade 7
# 2         306           6  04-06-2025      Quiz     87     B    Grade 8
#
#   section           name gender   age          city subject_name  \
# 0       A  Steven Austin      M  13.0  Johnsonmouth         Math
# 1       A    Larry Davis      M  17.0   Acevedofort      Science
# 2       C     Kevin Pugh      F  16.0  Andersonstad      English
#
#             name.1  experience_years subject_specialty
# 0     Monica Greer              30.0           Science
# 1  William Navarro              10.0         Geography
# 2       Erin Doyle               5.0           History

# %%
# difference bet loc and iloc:
df[0:3]
# Out:
#    student_id  subject_id   test_date test_type  score grade class_name  \
# 0         306           5  11-06-2024      Quiz     17     F    Grade 8
# 1         788           4  19-06-2024     Final     51     D    Grade 7
# 2         306           6  04-06-2025      Quiz     87     B    Grade 8
#
#   section           name gender   age          city subject_name  \
# 0       A  Steven Austin      M  13.0  Johnsonmouth         Math
# 1       A    Larry Davis      M  17.0   Acevedofort      Science
# 2       C     Kevin Pugh      F  16.0  Andersonstad      English
#
#             name.1  experience_years subject_specialty
# 0     Monica Greer              30.0           Science
# 1  William Navarro              10.0         Geography
# 2       Erin Doyle               5.0           History

# %%
vari=df.loc[[0,2,3,4,5, 6], ["score", "experience_years"]]
plt.plot(vari["score"], vari["experience_years"], color="Black")
plt.show()

# %%
vari=df.loc[[0,1,2,3,4,5], ["subject_id", "subject_name"]]
plt.bar(vari["subject_id"], vari["subject_name"], color="red")
plt.show()

# %%
vari=df.loc[[5,10,12,14,15,16], ["age", "city"]]
plt.pie(vari["age"], labels=vari["city"], autopct="%0.0F%%")
plt.show()

# %%
df.iloc[[2,4,6,8,10,12,16,18], [8,11, 14]]
# Out:
#                 name               city  experience_years
# 2         Kevin Pugh       Andersonstad               5.0
# 4       James Ibarra  North Michaelview               5.0
# 6       Timothy Ruiz          New Henry               1.0
# 8      Timothy Davis    New Jeanneburgh              18.0
# 10     Deborah Perry        South Casey               2.0
# 12   Stephanie Clark     Lake Karenfort              20.0
# 16  Katherine Taylor      Blackwellstad               1.0
# 18       Jason Craig          Bowenstad               5.0

# %%
vari=df.iloc[[2,4,6,8,10,12,16,18], [8,11, 14]]
sns.boxplot(x="city", y="experience_years", data=vari, hue="name")
plt.show()

# %%
vari=df.iloc[[2,4,6,8,10,12,16,18], [8,11, 14]]
sns.barplot(x="city", y="experience_years", data=vari, hue="name")
plt.show()

# %%
# Q1. Create a column pass_fail → "Pass" if score ≥ 40, else "Fail"
df["pass_fail"]=np.where(df["score"]>=40, "pass", "fail")
df
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 0             306           5  11-06-2024      Quiz     17     F    Grade 8
# 1             788           4  19-06-2024     Final     51     D    Grade 7
# 2             306           6  04-06-2025      Quiz     87     B    Grade 8
# 3             305           5  28-12-2023      Quiz     95     A    Grade 9
# 4             830           3  27-02-2025     Final     18     F    Grade 8
# ...           ...         ...         ...       ...    ...   ...        ...
# 19995         743           3  20-11-2023     Final     70     C        NaN
# 19996         766           3  01-06-2025     Final     96     A        NaN
# 19997         617           1  20-04-2024   Midterm     85     B        NaN
# 19998         121           2  30-04-2024      Quiz     24     F        NaN
# 19999         516           2  15-09-2024   Midterm     36     F        NaN
#
# ...

# %%
# Q2. Add a column score_percent assuming max score = 100
df["score_percent"]=df["score"]==100
df
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 0             306           5  11-06-2024      Quiz     17     F    Grade 8
# 1             788           4  19-06-2024     Final     51     D    Grade 7
# 2             306           6  04-06-2025      Quiz     87     B    Grade 8
# 3             305           5  28-12-2023      Quiz     95     A    Grade 9
# 4             830           3  27-02-2025     Final     18     F    Grade 8
# ...           ...         ...         ...       ...    ...   ...        ...
# 19995         743           3  20-11-2023     Final     70     C        NaN
# 19996         766           3  01-06-2025     Final     96     A        NaN
# 19997         617           1  20-04-2024   Midterm     85     B        NaN
# 19998         121           2  30-04-2024      Quiz     24     F        NaN
# 19999         516           2  15-09-2024   Midterm     36     F        NaN
#
# ...

# %%
# Q. Extract year from the test_date as test_year
df["year"]=df["test_date"].str[6:10]
df.head(5)
# Out:
#    student_id  subject_id   test_date test_type  score grade class_name  \
# 0         306           5  11-06-2024      Quiz     17     F    Grade 8
# 1         788           4  19-06-2024     Final     51     D    Grade 7
# 2         306           6  04-06-2025      Quiz     87     B    Grade 8
# 3         305           5  28-12-2023      Quiz     95     A    Grade 9
# 4         830           3  27-02-2025     Final     18     F    Grade 8
#
#   section           name gender   age                city subject_name  \
# 0       A  Steven Austin      M  13.0        Johnsonmouth         Math
# 1       A    Larry Davis      M  17.0         Acevedofort      Science
# 2       C     Kevin Pugh      F  16.0        Andersonstad      English
# 3       B   Sarah Snyder      M  10.0  Lake Cherylchester      History
# 4       C   James Ibarra      F  17.0   North Michaelview    Geography
#
#             name.1  experience_years subject_specialty pass_fail  \
# ...

# %%
# Q. Show student_id and score for first 5 rows

vari=df["student_id"].to_frame() 
sns.displot(x="student_id", data=vari)
plt.show()

# %%
vari=df[["student_id", "score"]].head(15)
plt.scatter(vari["student_id"], vari["score"], color="black")
plt.show()

# %%
# Q. Show all rows where subject_id = 5
df[df["subject_id"]==5]
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 0             306           5  11-06-2024      Quiz     17     F    Grade 8
# 3             305           5  28-12-2023      Quiz     95     A    Grade 9
# 6             853           5  04-09-2024     Final     46     D    Grade 6
# 17            108           5  12-07-2023     Final     53     D   Grade 10
# 21            244           5  21-02-2025     Final      4     F    Grade 9
# ...           ...         ...         ...       ...    ...   ...        ...
# 19971         855           5  30-07-2024     Final     91     A        NaN
# 19973         455           5  17-10-2023   Midterm     22     F        NaN
# 19979         739           5  07-01-2025     Final     63     C        NaN
# 19990         924           5  15-02-2024     Final     94     A        NaN
# 19993         842           5  30-10-2023     Final     43     D        NaN
#
# ...

# %%
# Q. Get all records where score"]>=90 is more than 90
df[df["score"]>90]
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 3             305           5  28-12-2023      Quiz     95     A    Grade 9
# 9             329           1  23-03-2024      Quiz     94     A    Grade 8
# 15            901           1  07-04-2024      Quiz     94     A    Grade 8
# 22            160           2  11-04-2024     Final     94     A    Grade 6
# 26            748           6  02-01-2024      Quiz     93     A    Grade 7
# ...           ...         ...         ...       ...    ...   ...        ...
# 19971         855           5  30-07-2024     Final     91     A        NaN
# 19977         537           3  26-07-2024     Final     92     A        NaN
# 19981         356           2  11-02-2025   Midterm     95     A        NaN
# 19990         924           5  15-02-2024     Final     94     A        NaN
# 19996         766           3  01-06-2025     Final     96     A        NaN
#
# ...

# %%
# Q. Find all students who got grade 'F' in a Quiz
df[(df["grade"]=="F") & (df["test_type"]=="Quiz")]
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 0             306           5  11-06-2024      Quiz     17     F    Grade 8
# 10            574           4  03-02-2024      Quiz     25     F    Grade 9
# 16            902           4  19-07-2023      Quiz      9     F   Grade 12
# 23            935           2  12-05-2025      Quiz      7     F   Grade 12
# 32             83           6  12-08-2024      Quiz     35     F        NaN
# ...           ...         ...         ...       ...    ...   ...        ...
# 19949          11           6  02-01-2024      Quiz     11     F        NaN
# 19952         775           6  10-06-2025      Quiz     32     F        NaN
# 19954         968           5  10-10-2024      Quiz     37     F        NaN
# 19962         313           2  03-11-2023      Quiz      9     F        NaN
# 19998         121           2  30-04-2024      Quiz     24     F        NaN
#
# ...

# %%
# Q. Find all who failed in 2025
df["pass_fail"]=="fail"
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998     True
# 19999     True
# Name: pass_fail, Length: 20000, dtype: bool

# %%
# Q. Fill missing grades with 'Unknown'
df["class_name"].replace(np.NaN, "Unknown")
# Out:
# 0        Grade 8
# 1        Grade 7
# 2        Grade 8
# 3        Grade 9
# 4        Grade 8
#           ...
# 19995    Unknown
# 19996    Unknown
# 19997    Unknown
# 19998    Unknown
# 19999    Unknown
# Name: class_name, Length: 20000, dtype: object

# %%
# Q. Count of each grade
df["grade"].value_counts()
# Out:
# grade
# F    7926
# D    3977
# C    2989
# B    2891
# A    2217
# Name: count, dtype: int64

# %%
# Q. Average score by test type
df.groupby("test_type")["score"].mean()
# Out:
# test_type
# Final      50.131895
# Midterm    50.074857
# Quiz       49.753295
# Name: score, dtype: float64

# %%
# Q. Max and min scores by year
vadf.groupby("year")["score"].median()

# %%
# Q. Total records per test_type
df["test_type"].value_counts()
sns.countplot(x="test_type", data=df)
plt.show()

# %%
# Q. Top 10 scorers overall
df.sort_values(["score"], ascending=False)
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 3644          199           4  23-10-2024     Final    100     A        NaN
# 9772          396           4  24-04-2024   Midterm    100     A        NaN
# 11025         451           5  18-11-2024     Final    100     A        NaN
# 3662          853           2  27-04-2025     Final    100     A        NaN
# 11373         489           4  21-02-2024     Final    100     A        NaN
# ...           ...         ...         ...       ...    ...   ...        ...
# 19798         527           6  12-12-2023      Quiz      0     F        NaN
# 9975          353           3  24-11-2023      Quiz      0     F        NaN
# 10007         161           3  23-10-2024   Midterm      0     F        NaN
# 10016         235           5  04-10-2024   Midterm      0     F        NaN
# 6453          348           6  31-01-2024   Midterm      0     F        NaN
#
# ...

# %%
for “High Performer” (e.g., score > 90) or “Grade Status”!

# %%
# Q. Sort records by date (old to new)
df.sort_values(["test_date"], ascending=True)
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 4453          866           4  01-01-2024      Quiz     40     D        NaN
# 8492          887           5  01-01-2024   Midterm     76     B        NaN
# 19728         207           2  01-01-2024     Final     30     F        NaN
# 702           571           5  01-01-2024      Quiz     16     F        NaN
# 19731         323           4  01-01-2024     Final     20     F        NaN
# ...           ...         ...         ...       ...    ...   ...        ...
# 1936          541           6  31-12-2024   Midterm     20     F        NaN
# 16470         351           3  31-12-2024     Final     57     D        NaN
# 17083         956           1  31-12-2024     Final     76     B        NaN
# 13263         355           3  31-12-2024   Midterm     30     F        NaN
# 4836          170           4  31-12-2024     Final     71     C        NaN
#
# ...

# %%
# Q. Top 5 Final test scorers
df[df["test_type"]=="Final"].sort_values(["score"], ascending=False)
# Out:
#        student_id  subject_id   test_date test_type  score grade class_name  \
# 5203          643           4  28-05-2025     Final    100     A        NaN
# 2849           64           2  31-03-2024     Final    100     A        NaN
# 6836          970           4  08-06-2025     Final    100     A        NaN
# 5005          644           4  30-09-2024     Final    100     A        NaN
# 15507         677           5  07-11-2023     Final    100     A        NaN
# ...           ...         ...         ...       ...    ...   ...        ...
# 19111         595           6  18-02-2025     Final      0     F        NaN
# 14032         126           6  13-05-2024     Final      0     F        NaN
# 6122          882           6  11-11-2023     Final      0     F        NaN
# 742           269           6  23-10-2024     Final      0     F        NaN
# 9826          139           5  07-08-2024     Final      0     F        NaN
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:/Users/jumal/OneDrive/Desktop/Data Analyst/SQL/Student Performance Analytics/Student Performance Analytics.csv")
df
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Display top 5 rows dataset
df.head()
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
# 3         4         305           5  28-12-2023      Quiz     95     A
# 4         5         830           3  27-02-2025     Final     18     F
#
#    class_id class_name section  ...   age  class_id.1                city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0        Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0         Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0        Andersonstad
# 3       4.0    Grade 9       B  ...  10.0        24.0  Lake Cherylchester
# 4       5.0    Grade 8       C  ...  17.0         5.0   North Michaelview
#
#   subject_id.1  subject_name  teacher_id teacher_id.1           name.1  \
# ...

# %%
# last 5 rows data from dataset
df.tail()
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
#        class_id class_name section  ...  age  class_id.1 city subject_id.1  \
# 19995       NaN        NaN     NaN  ...  NaN         NaN  NaN          NaN
# 19996       NaN        NaN     NaN  ...  NaN         NaN  NaN          NaN
# 19997       NaN        NaN     NaN  ...  NaN         NaN  NaN          NaN
# 19998       NaN        NaN     NaN  ...  NaN         NaN  NaN          NaN
# 19999       NaN        NaN     NaN  ...  NaN         NaN  NaN          NaN
#
# ...

# %%
# Display summary 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   score_id           20000 non-null  int64
#  1   student_id         20000 non-null  int64
#  2   subject_id         20000 non-null  int64
#  3   test_date          20000 non-null  object
#  4   test_type          20000 non-null  object
#  5   score              20000 non-null  int64
#  6   grade              20000 non-null  object
#  7   class_id           30 non-null     float64
#  8   class_name         30 non-null     object
#  9   section            30 non-null     object
#  10  class_teacher_id   30 non-null     float64
#  11  student_id.1       1000 non-null   float64
#  12  name               1000 non-null   object
#  13  gender             1000 non-null   object
#  14  age                1000 non-null   float64
#  15  class_id.1         1000 non-null   float64
# ...

# %%
# display only Numaricals dataset
df.describe()
# Out:
#            score_id   student_id    subject_id         score   class_id  \
# count  20000.000000  20000.00000  20000.000000  20000.000000  30.000000
# mean   10000.500000    499.22195      3.502250     49.985050  15.500000
# std     5773.647028    287.67677      1.708374     29.113483   8.803408
# min        1.000000      1.00000      1.000000      0.000000   1.000000
# 25%     5000.750000    249.00000      2.000000     25.000000   8.250000
# 50%    10000.500000    501.00000      4.000000     50.000000  15.500000
# 75%    15000.250000    747.00000      5.000000     75.000000  22.750000
# max    20000.000000   1000.00000      6.000000    100.000000  30.000000
#
#        class_teacher_id  student_id.1          age   class_id.1  subject_id.1  \
# count         30.000000   1000.000000  1000.000000  1000.000000      6.000000
# mean          10.800000    500.500000    14.053000    15.527000      3.500000
# std            5.950369    288.819436     2.581638     8.749504      1.870829
# ...

# %%
# check type of dataset
df.dtypes
# Out:
# score_id               int64
# student_id             int64
# subject_id             int64
# test_date             object
# test_type             object
# score                  int64
# grade                 object
# class_id             float64
# class_name            object
# section               object
# class_teacher_id     float64
# student_id.1         float64
# name                  object
# gender                object
# age                  float64
# class_id.1           float64
# city                  object
# subject_id.1         float64
# subject_name          object
# teacher_id           float64
# teacher_id.1         float64
# name.1                object
# experience_years     float64
# subject_specialty     object
# dtype: object

# %%
# Check dimension of dataframe
df.ndim
# Out:
# 2

# %%
# Lets check all columns present in dataframe
df.columns
# Out:
# Index(['score_id', 'student_id', 'subject_id', 'test_date', 'test_type',
#        'score', 'grade', 'class_id', 'class_name', 'section',
#        'class_teacher_id', 'student_id.1', 'name', 'gender', 'age',
#        'class_id.1', 'city', 'subject_id.1', 'subject_name', 'teacher_id',
#        'teacher_id.1', 'name.1', 'experience_years', 'subject_specialty'],
#       dtype='object')

# %%
# Identify duplicate records in Rows
df.duplicated().sum()
# Out:
# 0

# %%
# Check Duplicate values in Columns
df["student_id"].duplicated().sum()
# Out:
# 19000

# %%
df[["student_id", "age"]].duplicated().sum()
# Out:
# 18048

# %%
#Find shape of dataframe i.e number of rows and columns.
df.shape
# Out:
# (20000, 24)

# %%
# delete all duplicate rows
df.drop_duplicates()
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# delete duplicate columns
df.drop_duplicates(["student_id", "age"])
# Out:
#       score_id  student_id  subject_id   test_date test_type  score grade  \
# 0            1         306           5  11-06-2024      Quiz     17     F
# 1            2         788           4  19-06-2024     Final     51     D
# 2            3         306           6  04-06-2025      Quiz     87     B
# 3            4         305           5  28-12-2023      Quiz     95     A
# 4            5         830           3  27-02-2025     Final     18     F
# ...        ...         ...         ...         ...       ...    ...   ...
# 7201      7202         572           5  05-11-2023      Quiz     49     D
# 7229      7230         364           2  08-05-2024   Midterm     46     D
# 7262      7263         509           6  21-03-2024   Midterm     91     A
# 7328      7329          37           4  10-11-2023      Quiz     59     D
# 7729      7730         325           2  13-03-2025      Quiz      0     F
#
#       class_id class_name section  ...   age  class_id.1                city  \
# ...

# %%
# How do you find missing data in a DataFrame?
df.isnull().sum()
# Out:
# score_id                 0
# student_id               0
# subject_id               0
# test_date                0
# test_type                0
# score                    0
# grade                    0
# class_id             19970
# class_name           19970
# section              19970
# class_teacher_id     19970
# student_id.1         19000
# name                 19000
# gender               19000
# age                  19000
# class_id.1           19000
# city                 19000
# subject_id.1         19994
# subject_name         19994
# teacher_id           19994
# teacher_id.1         19980
# name.1               19980
# experience_years     19980
# subject_specialty    19980
# dtype: int64

# %%
# Check for columns having null values and count of null contaning rows.
df[["subject_name","section", "age"]].isnull().sum()
# Out:
# subject_name    19994
# section         19970
# age             19000
# dtype: int64

# %%
df.dropna(axis=0, inplace=False)
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
# 3         4         305           5  28-12-2023      Quiz     95     A
# 4         5         830           3  27-02-2025     Final     18     F
# 5         6         625           2  15-04-2024   Midterm     25     F
#
#    class_id class_name section  ...   age  class_id.1                city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0        Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0         Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0        Andersonstad
# 3       4.0    Grade 9       B  ...  10.0        24.0  Lake Cherylchester
# 4       5.0    Grade 8       C  ...  17.0         5.0   North Michaelview
# ...

# %%
df.dropna(axis=1, inplace=False)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# [20000 rows x 7 columns]

# %%
df.dropna(subset=["subject_name"], inplace=False)
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
# 3         4         305           5  28-12-2023      Quiz     95     A
# 4         5         830           3  27-02-2025     Final     18     F
# 5         6         625           2  15-04-2024   Midterm     25     F
#
#    class_id class_name section  ...   age  class_id.1                city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0        Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0         Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0        Andersonstad
# 3       4.0    Grade 9       B  ...  10.0        24.0  Lake Cherylchester
# 4       5.0    Grade 8       C  ...  17.0         5.0   North Michaelview
# ...

# %%
df.ffill()
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
df.bfill()
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Replace NaN with any other value from mean, median, mode etc
df.replace(np.NaN, "kaka")
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 0             1         306           5  11-06-2024      Quiz     17     F
# 1             2         788           4  19-06-2024     Final     51     D
# 2             3         306           6  04-06-2025      Quiz     87     B
# 3             4         305           5  28-12-2023      Quiz     95     A
# 4             5         830           3  27-02-2025     Final     18     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Replace NaN with any other value from mean, median, mode etc
df["age"].replace(np.NaN, 10)
# Out:
# 0        13.0
# 1        17.0
# 2        16.0
# 3        10.0
# 4        17.0
#          ...
# 19995    10.0
# 19996    10.0
# 19997    10.0
# 19998    10.0
# 19999    10.0
# Name: age, Length: 20000, dtype: float64

# %%
# Find the Mean
df["age"].mean()
# Out:
# 14.053

# %%
# Find the Median
df["age"].median()
# Out:
# 14.0

# %%
# Find the Mode
df["age"].mode()
# Out:
# 0    14.0
# Name: age, dtype: float64

# %%
# Delete/Drop/Remove rows 2,6,5,3 from dataset
df.drop([0,1,2,3,4,5,6,7], axis=0, inplace=False)
# Out:
#        score_id  student_id  subject_id   test_date test_type  score grade  \
# 8             9         896           2  23-06-2025     Final     79     B
# 9            10         329           1  23-03-2024      Quiz     94     A
# 10           11         574           4  03-02-2024      Quiz     25     F
# 11           12         552           3  02-05-2024     Final     19     F
# 12           13         175           6  09-03-2024     Final     26     F
# ...         ...         ...         ...         ...       ...    ...   ...
# 19995     19996         743           3  20-11-2023     Final     70     C
# 19996     19997         766           3  01-06-2025     Final     96     A
# 19997     19998         617           1  20-04-2024   Midterm     85     B
# 19998     19999         121           2  30-04-2024      Quiz     24     F
# 19999     20000         516           2  15-09-2024   Midterm     36     F
#
# ...

# %%
# Delete/Drop/Remove  columns gender, SeniorCitizen from dataset
df.drop(["age", "student_id"], axis=1, inplace=False)
# Out:
#        score_id  subject_id   test_date test_type  score grade  class_id  \
# 0             1           5  11-06-2024      Quiz     17     F       1.0
# 1             2           4  19-06-2024     Final     51     D       2.0
# 2             3           6  04-06-2025      Quiz     87     B       3.0
# 3             4           5  28-12-2023      Quiz     95     A       4.0
# 4             5           3  27-02-2025     Final     18     F       5.0
# ...         ...         ...         ...       ...    ...   ...       ...
# 19995     19996           3  20-11-2023     Final     70     C       NaN
# 19996     19997           3  01-06-2025     Final     96     A       NaN
# 19997     19998           1  20-04-2024   Midterm     85     B       NaN
# 19998     19999           2  30-04-2024      Quiz     24     F       NaN
# 19999     20000           2  15-09-2024   Midterm     36     F       NaN
#
#       class_name section  class_teacher_id  ...  gender class_id.1  \
# ...

# %%
# Show only perticular Columns from Dataset
df[["test_type", "age"]]
# Out:
#       test_type   age
# 0          Quiz  13.0
# 1         Final  17.0
# 2          Quiz  16.0
# 3          Quiz  10.0
# 4         Final  17.0
# ...         ...   ...
# 19995     Final   NaN
# 19996     Final   NaN
# 19997   Midterm   NaN
# 19998      Quiz   NaN
# 19999   Midterm   NaN
#
# [20000 rows x 2 columns]

# %%
# difference bet loc and iloc:
# loc= using row-column label/names
# iloc=using row-column index/numbers 
df.loc[0:3]
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
# 3         4         305           5  28-12-2023      Quiz     95     A
#
#    class_id class_name section  ...   age  class_id.1                city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0        Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0         Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0        Andersonstad
# 3       4.0    Grade 9       B  ...  10.0        24.0  Lake Cherylchester
#
#   subject_id.1  subject_name  teacher_id teacher_id.1           name.1  \
# 0          1.0          Math        18.0          1.0     Monica Greer
# 1          2.0       Science         6.0          2.0  William Navarro
# ...

# %%
df.iloc[[0,2,5,7,10,12,15,20], [3]]
# Out:
#     score
# 0      17
# 2      87
# 5      25
# 7       0
# 10     25
# 12     26
# 15     94
# 20     42

# %%
df.iloc[[0,2,5,7,10], [3]]
sns.countplot(x="score", data=df)
plt.show()

# %%
vari=df.iloc[[0,2,5,7,10,12,15,20], [3]]
sns.displot(x="score", data=vari)
plt.show()

# %%
vari=df.iloc[[0,2,5,7,10,12,15,20], [0,3]]
plt.scatter(vari["student_id"], vari["score"])
plt.show()

# %%
vari=df.iloc[[0,2,5,7,10,12,15,20], [0,3]]
plt.plot(vari["student_id"], vari["score"])
plt.show()

# %%
df.loc[[50,100,150,200,250,300,350], ["student_id", "city"]]
# Out:
#      student_id             city
# 50          827         Johnview
# 100         131        East Ryan
# 150         431      Howardmouth
# 200          76  Port Johnnyport
# 250         143       Meyersland
# 300         144      New Jessica
# 350         955  Hutchinsonmouth

# %%
vari=df.loc[[50,100,150,200,250,300,350], ["student_id", "city"]]
sns.boxplot(x="city", y="student_id", data=vari)
plt.show()

# %%
vari=df.loc[[50,100,150,200,250,300,350], ["student_id", "city"]]
sns.barplot(x="city", y="student_id", data=vari)
plt.show()

# %%
vari=df.loc[[50,100,150,200,250,300,350], ["student_id", "city"]]
plt.pie(vari["student_id"], labels=vari["city"], autopct="%0.0F%%")
plt.show()

# %%
vari=df.loc[[50,100,150,200,250,300,350], ["student_id", "city"]]
plt.bar(vari["city"], vari["student_id"])
plt.show()

# %%
df.iloc[0:3]
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
#
#    class_id class_name section  ...   age  class_id.1          city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0  Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0   Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0  Andersonstad
#
#   subject_id.1  subject_name  teacher_id teacher_id.1           name.1  \
# 0          1.0          Math        18.0          1.0     Monica Greer
# 1          2.0       Science         6.0          2.0  William Navarro
# 2          3.0       English         6.0          3.0       Erin Doyle
#
#   experience_years  subject_specialty
# 0             30.0            Science
# 1             10.0          Geography
# ...

# %%
df[0:3]
# Out:
#    score_id  student_id  subject_id   test_date test_type  score grade  \
# 0         1         306           5  11-06-2024      Quiz     17     F
# 1         2         788           4  19-06-2024     Final     51     D
# 2         3         306           6  04-06-2025      Quiz     87     B
#
#    class_id class_name section  ...   age  class_id.1          city  \
# 0       1.0    Grade 8       A  ...  13.0        13.0  Johnsonmouth
# 1       2.0    Grade 7       A  ...  17.0         9.0   Acevedofort
# 2       3.0    Grade 8       C  ...  16.0        16.0  Andersonstad
#
#   subject_id.1  subject_name  teacher_id teacher_id.1           name.1  \
# 0          1.0          Math        18.0          1.0     Monica Greer
# 1          2.0       Science         6.0          2.0  William Navarro
# 2          3.0       English         6.0          3.0       Erin Doyle
#
#   experience_years  subject_specialty
# 0             30.0            Science
# 1             10.0          Geography
# ...

# %%
df.drop(["score_id", "subject_id", "class_id.1", "subject_id.1", "teacher_id", "teacher_id.1"], axis=1,  inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 df.drop(["score_id", "subject_id", "class_id.1", "subject_id.1", "teacher_id", "teacher_id.1"], axis=1,  inplace=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df.drop(["class_teacher_id", "student_id.1","class_id"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
# 3         305  28-12-2023      Quiz     95     A    Grade 9       B
# 4         830  27-02-2025     Final     18     F    Grade 8       C
#
#             name gender   age                city subject_name  \
# 0  Steven Austin      M  13.0        Johnsonmouth         Math
# 1    Larry Davis      M  17.0         Acevedofort      Science
# 2     Kevin Pugh      F  16.0        Andersonstad      English
# 3   Sarah Snyder      M  10.0  Lake Cherylchester      History
# 4   James Ibarra      F  17.0   North Michaelview    Geography
#
#             name.1  experience_years subject_specialty
# 0     Monica Greer              30.0           Science
# 1  William Navarro              10.0         Geography
# ...

# %%
# Q1. Create a new column score_percent assuming total marks = 100.
df["score_percent"]=(df["score"]/100)*100

# %%
df[0:3]
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
#
#             name gender   age          city subject_name           name.1  \
# 0  Steven Austin      M  13.0  Johnsonmouth         Math     Monica Greer
# 1    Larry Davis      M  17.0   Acevedofort      Science  William Navarro
# 2     Kevin Pugh      F  16.0  Andersonstad      English       Erin Doyle
#
#    experience_years subject_specialty  score_percent
# 0              30.0           Science           17.0
# 1              10.0         Geography           51.0
# 2               5.0           History           87.0

# %%
# Q. Create a new column result that marks ‘Pass’ if score ≥ 40, else ‘Fail’.
df["result"]=np.where(df["score"]>=40, "Pass", "Fail")

# %%
df[0:3]
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
#
#             name gender   age          city subject_name           name.1  \
# 0  Steven Austin      M  13.0  Johnsonmouth         Math     Monica Greer
# 1    Larry Davis      M  17.0   Acevedofort      Science  William Navarro
# 2     Kevin Pugh      F  16.0  Andersonstad      English       Erin Doyle
#
#    experience_years subject_specialty  score_percent result
# 0              30.0           Science           17.0   Fail
# 1              10.0         Geography           51.0   Pass
# 2               5.0           History           87.0   Pass

# %%
# Q. Combine class and section as one column called class_section"]=df["
df["class_section"]=df["class_name"]+ df["section"]

# %%
df[0:3]
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
#
#             name gender   age          city subject_name           name.1  \
# 0  Steven Austin      M  13.0  Johnsonmouth         Math     Monica Greer
# 1    Larry Davis      M  17.0   Acevedofort      Science  William Navarro
# 2     Kevin Pugh      F  16.0  Andersonstad      English       Erin Doyle
#
#    experience_years subject_specialty  score_percent result class_section
# 0              30.0           Science           17.0   Fail      Grade 8A
# 1              10.0         Geography           51.0   Pass      Grade 7A
# 2               5.0           History           87.0   Pass      Grade 8C

# %%
# Q. Show data for student with student_id = 306
df[(df["student_id"]==306)]
# Out:
#        student_id   test_date test_type  score grade class_name section  \
# 0             306  11-06-2024      Quiz     17     F    Grade 8       A
# 2             306  04-06-2025      Quiz     87     B    Grade 8       C
# 210           306  14-02-2024   Midterm     36     F        NaN     NaN
# 2992          306  06-09-2023      Quiz     47     D        NaN     NaN
# 4793          306  23-08-2024   Midterm     55     D        NaN     NaN
# 5498          306  21-05-2024   Midterm     98     A        NaN     NaN
# 5516          306  14-04-2024      Quiz     39     F        NaN     NaN
# 5859          306  17-12-2024      Quiz     19     F        NaN     NaN
# 7448          306  03-03-2024     Final     62     C        NaN     NaN
# 9819          306  29-08-2024   Midterm     97     A        NaN     NaN
# 10515         306  24-01-2025     Final     83     B        NaN     NaN
# 13104         306  21-02-2025      Quiz     25     F        NaN     NaN
# ...

# %%
# Q. Get all female (gender='F') students who failed.
df[(df["gender"]=="F") & (df["result"]=="Fail")]
# Out:
#      student_id   test_date test_type  score grade class_name section  \
# 4           830  27-02-2025     Final     18     F    Grade 8       C
# 5           625  15-04-2024   Midterm     25     F   Grade 12       C
# 7           629  11-12-2023     Final      0     F   Grade 12       B
# 11          552  02-05-2024     Final     19     F    Grade 6       C
# 12          175  09-03-2024     Final     26     F   Grade 11       A
# ..          ...         ...       ...    ...   ...        ...     ...
# 960         744  20-02-2024   Midterm      3     F        NaN     NaN
# 971         700  11-02-2025     Final     16     F        NaN     NaN
# 972         385  24-12-2023     Final     36     F        NaN     NaN
# 983         926  07-10-2023   Midterm     29     F        NaN     NaN
# 998          18  29-10-2024     Final     26     F        NaN     NaN
#
#                    name gender   age               city subject_name  \
# ...

# %%
df[0:3]
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
#
#             name gender   age          city subject_name           name.1  \
# 0  Steven Austin      M  13.0  Johnsonmouth         Math     Monica Greer
# 1    Larry Davis      M  17.0   Acevedofort      Science  William Navarro
# 2     Kevin Pugh      F  16.0  Andersonstad      English       Erin Doyle
#
#    experience_years subject_specialty  score_percent result class_section
# 0              30.0           Science           17.0   Fail      Grade 8A
# 1              10.0         Geography           51.0   Pass      Grade 7A
# 2               5.0           History           87.0   Pass      Grade 8C

# %%
# Q. Check how many rows have missing age.
df["age"].isnull().sum()
# Out:
# 19000

# %%
# Q. Count of students by gender.
df.groupby("gender")["student_id"].count()
# Out:
# gender
# F    517
# M    483
# Name: student_id, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# F    517
# M    483
# Name: count, dtype: int64

# %%
df.dropna(subset=["age"], inplace=False)
# Out:
#      student_id   test_date test_type  score grade class_name section  \
# 0           306  11-06-2024      Quiz     17     F    Grade 8       A
# 1           788  19-06-2024     Final     51     D    Grade 7       A
# 2           306  04-06-2025      Quiz     87     B    Grade 8       C
# 3           305  28-12-2023      Quiz     95     A    Grade 9       B
# 4           830  27-02-2025     Final     18     F    Grade 8       C
# ..          ...         ...       ...    ...   ...        ...     ...
# 995         712  03-03-2025      Quiz     68     C        NaN     NaN
# 996         359  08-09-2024   Midterm     74     C        NaN     NaN
# 997         673  25-06-2024      Quiz     70     C        NaN     NaN
# 998          18  29-10-2024     Final     26     F        NaN     NaN
# 999         253  18-10-2024   Midterm     14     F        NaN     NaN
#
#                name gender   age                city subject_name  \
# ...

# %%
#Q. Get students who scored above 90 in a Final test.
df[(df["score"]>90) & (df["test_type"]=="Final")]
# Out:
#        student_id   test_date test_type  score grade class_name section  \
# 22            160  11-04-2024     Final     94     A    Grade 6       A
# 34            255  08-11-2023     Final     96     A        NaN     NaN
# 84            482  20-05-2024     Final     98     A        NaN     NaN
# 86            437  12-11-2023     Final     93     A        NaN     NaN
# 100           131  27-06-2025     Final     91     A        NaN     NaN
# ...           ...         ...       ...    ...   ...        ...     ...
# 19955         531  14-04-2025     Final     99     A        NaN     NaN
# 19971         855  30-07-2024     Final     91     A        NaN     NaN
# 19977         537  26-07-2024     Final     92     A        NaN     NaN
# 19990         924  15-02-2024     Final     94     A        NaN     NaN
# 19996         766  01-06-2025     Final     96     A        NaN     NaN
#
#                   name gender   age           city subject_name name.1  \
# ...

# %%
#Q. Average score for each grade (A, B, C, D, F).
df.groupby("grade")["score"].mean()
# Out:
# grade
# A    94.914750
# B    81.900035
# C    67.123787
# D    49.497360
# F    19.558163
# Name: score, dtype: float64

# %%
df["grade"].value_counts()
# Out:
# grade
# F    7926
# D    3977
# C    2989
# B    2891
# A    2217
# Name: count, dtype: int64

# %%
# Q12. Average score by subject.
df.groupby("subject_name")["score"].mean()
# Out:
# subject_name
# Computer     25.0
# English      87.0
# Geography    18.0
# History      95.0
# Math         17.0
# Science      51.0
# Name: score, dtype: float64

# %%
# Q13. Sort students by highest score.
df.sort_values(["score"], ascending=False).head()
# Out:
#        student_id   test_date test_type  score grade class_name section name  \
# 3644          199  23-10-2024     Final    100     A        NaN     NaN  NaN
# 9772          396  24-04-2024   Midterm    100     A        NaN     NaN  NaN
# 11025         451  18-11-2024     Final    100     A        NaN     NaN  NaN
# 3662          853  27-04-2025     Final    100     A        NaN     NaN  NaN
# 11373         489  21-02-2024     Final    100     A        NaN     NaN  NaN
#
#       gender  age city subject_name name.1  experience_years  \
# 3644     NaN  NaN  NaN          NaN    NaN               NaN
# 9772     NaN  NaN  NaN          NaN    NaN               NaN
# 11025    NaN  NaN  NaN          NaN    NaN               NaN
# 3662     NaN  NaN  NaN          NaN    NaN               NaN
# 11373    NaN  NaN  NaN          NaN    NaN               NaN
#
#       subject_specialty  score_percent result class_section
# 3644                NaN          100.0   Pass           NaN
# ...

# %%
# Q. Sort by class then score descending.
df.sort_values(["class_name", "score"], ascending=False)
# Out:
#        student_id   test_date test_type  score grade class_name section  \
# 3             305  28-12-2023      Quiz     95     A    Grade 9       B
# 20            775  28-10-2023      Quiz     42     D    Grade 9       A
# 10            574  03-02-2024      Quiz     25     F    Grade 9       B
# 21            244  21-02-2025     Final      4     F    Grade 9       B
# 9             329  23-03-2024      Quiz     94     A    Grade 8       A
# ...           ...         ...       ...    ...   ...        ...     ...
# 19727         463  25-05-2025     Final      0     F        NaN     NaN
# 19798         527  12-12-2023      Quiz      0     F        NaN     NaN
# 19839         501  17-09-2024     Final      0     F        NaN     NaN
# 19862         132  30-09-2023      Quiz      0     F        NaN     NaN
# 19880         146  21-02-2025      Quiz      0     F        NaN     NaN
#
#                  name gender   age                city subject_name  \
# ...

# %%
# Q15. Extract year and month from test_date.
df["month"]=df["test_date"].str[6:10]

# %%
df[0:3]
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
#
#             name gender   age          city subject_name           name.1  \
# 0  Steven Austin      M  13.0  Johnsonmouth         Math     Monica Greer
# 1    Larry Davis      M  17.0   Acevedofort      Science  William Navarro
# 2     Kevin Pugh      F  16.0  Andersonstad      English       Erin Doyle
#
#    experience_years subject_specialty  score_percent result class_section  \
# 0              30.0           Science           17.0   Fail      Grade 8A
# 1              10.0         Geography           51.0   Pass      Grade 7A
# 2               5.0           History           87.0   Pass      Grade 8C
#
#   month
# 0  2024
# 1  2024
# 2  2025

# %%
# Q16. Create a column days_ago showing how many days ago the test was taken.
from datetime import datetime
df["days_ago"] = (datetime.today() - pd.to_datetime(df["test_date"], dayfirst=True)).dt.days

# %%
# Q17. Label performance: “Excellent” (score ≥ 90) “Average” (40–89) “Poor” (< 40)
df["performance"]=np.where(df["score"]>=90, "Excellent", 
                  np.where(df["score"]>=40, "Average", "poor"))

# %%
df[0:3]
# Out:
#    student_id   test_date test_type  score grade class_name section  \
# 0         306  11-06-2024      Quiz     17     F    Grade 8       A
# 1         788  19-06-2024     Final     51     D    Grade 7       A
# 2         306  04-06-2025      Quiz     87     B    Grade 8       C
#
#             name gender   age  ... subject_name           name.1  \
# 0  Steven Austin      M  13.0  ...         Math     Monica Greer
# 1    Larry Davis      M  17.0  ...      Science  William Navarro
# 2     Kevin Pugh      F  16.0  ...      English       Erin Doyle
#
#   experience_years  subject_specialty score_percent  result class_section  \
# 0             30.0            Science          17.0    Fail      Grade 8A
# 1             10.0          Geography          51.0    Pass      Grade 7A
# 2              5.0            History          87.0    Pass      Grade 8C
#
#   month days_ago  performance
# 0  2024      396         poor
# 1  2024      388      Average
# 2  2025       38      Average
#
# ...

# %%
#Q18. Average student score per teacher.
df.groupby("name.1")Q19. Total students taught by each subject teacher.
python
Copy
Edit
["score"].mean()
# Out:
# name.1
# Amber Reed         18.0
# Annette Taylor      9.0
# Casey Frank        94.0
# Chelsea Torres     95.0
# Cheryl Ward        53.0
# Cody Johnson       25.0
# Cory James         79.0
# Daniel Medina      26.0
# Desiree Willis      0.0
# Dorothy Smith      85.0
# Erin Doyle         87.0
# Frank Garcia       25.0
# Jared Armstrong    48.0
# Kari Gibson        46.0
# Kim Cantu          74.0
# Monica Greer       17.0
# Nicholas White     19.0
# Shelly Jones       94.0
# Toni Ball           7.0
# William Navarro    51.0
# Name: score, dtype: float64

# %%
# Q19. Total students taught by each subject teacher.
df.groupby("name")["student_id"].count()
# Out:
# name
# Aaron Castillo        1
# Aaron Hernandez       1
# Aaron Jones           1
# Aaron Ortiz           1
# Abigail Lawson        1
#                      ..
# William Torres        1
# William Villarreal    1
# William Weber         1
# Willie Camacho        1
# Yolanda Reyes         1
# Name: student_id, Length: 991, dtype: int64
